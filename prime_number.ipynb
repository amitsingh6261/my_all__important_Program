# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsingh6261/my_all_Program/blob/main/prime_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter the number"))
if n>1:
  for i in range(2,n):

   if n%i==0:
    print("number is not prime")


   else:
    print("number is prime")
   break
else:
  print("number is not prime")

# %%
n=int(input("enter the number"))
for i in range(1,n):

  i=i*n
  print("i=",i)
# Out:
# enter the number4
# i= 4
# i= 8
# i= 12

# %%
n=4
for i in range(n):
  if n%4==0:
    print("hii")
    while i<n:
      break
    else:
      print("hello")
  else:
    print(i+2)
# Out:
# hii
# hii
# hii
# hii
